# %%
import pandas as pd 
dataframe = pd.read_csv("winequality-white.csv")
print(dataframe.keys())
dataframe.head()
print(dataframe.dtypes)
dataframe.hist(bins=100)
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object
# array([[<Axes: title={'center': 'fixed acidity'}>,
#         <Axes: title={'center': 'volatile acidity'}>,
#         <Axes: title={'center': 'citric acid'}>],
#        [<Axes: title={'center': 'residual sugar'}>,
#         <Axes: title={'center': 'chlorides'}>,
#         <Axes: title={'center': 'free sulfur dioxide'}>],
# ...

# %%
correlate=dataframe.corr()
print(correlate)
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.022697     0.289181
# volatile acidity          -0.022697          1.000000    -0.149472
# citric acid                0.289181         -0.149472     1.000000
# residual sugar             0.089021          0.064286     0.094212
# chlorides                  0.023086          0.070512     0.114364
# free sulfur dioxide       -0.049396         -0.097012     0.094077
# total sulfur dioxide       0.091070          0.089261     0.121131
# density                    0.265331          0.027114     0.149503
# pH                        -0.425858         -0.031915    -0.163748
# sulphates                 -0.017143         -0.035728     0.062331
# alcohol                   -0.120881          0.067718    -0.075729
# quality                   -0.113663         -0.194723    -0.009209
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
dataframe.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %%
copyDataSet = dataframe.copy()

from pandas.plotting import scatter_matrix

scatter =["density","pH","alcohol","quality" ]
scatter_matrix(copyDataSet[scatter])
# Out:
# array([[<Axes: xlabel='density', ylabel='density'>,
#         <Axes: xlabel='pH', ylabel='density'>,
#         <Axes: xlabel='alcohol', ylabel='density'>,
#         <Axes: xlabel='quality', ylabel='density'>],
#        [<Axes: xlabel='density', ylabel='pH'>,
#         <Axes: xlabel='pH', ylabel='pH'>,
#         <Axes: xlabel='alcohol', ylabel='pH'>,
#         <Axes: xlabel='quality', ylabel='pH'>],
#        [<Axes: xlabel='density', ylabel='alcohol'>,
#         <Axes: xlabel='pH', ylabel='alcohol'>,
#         <Axes: xlabel='alcohol', ylabel='alcohol'>,
#         <Axes: xlabel='quality', ylabel='alcohol'>],
#        [<Axes: xlabel='density', ylabel='quality'>,
#         <Axes: xlabel='pH', ylabel='quality'>,
#         <Axes: xlabel='alcohol', ylabel='quality'>,
#         <Axes: xlabel='quality', ylabel='quality'>]], dtype=object)

# %% [markdown]
# ### Did you discover interesting relations?
# Some interesting relations are that the amount of residual sugar is actually negatively correlated with reported quality, and the most negatively correlated features are density and alcohol (which is %volume). Another interesting thing to me is that it seems that the most correlated with the density of the wine is the residual sugar. Another interesting thing about the data not necessarily the relations is that despite the quality being on a scale of 0-10 on the data's description, the max in the data is 9 and the minimum is 3. After looking at some of the data in scatter matrix's I stopped at the image above and noticed pH's correlateion with alcohol% by volume is

# %% [markdown]
# ### What feature/s would you like to be able to predict?
# The features I would like to be able to predict for the dataset are quality, and residual sugar.

# %%
#got no nulls back from info
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %%
import sklearn
from sklearn.model_selection import train_test_split
import numpy as np

dataframeCopy = dataframe.copy()
wine_train_set, wine_test_set = train_test_split(dataframeCopy, test_size=0.4, random_state=103)
#working set of the training set, and test set made from the notes
winetrain= wine_train_set.copy()
winetest= wine_test_set.copy()
